# %%
from eod import EodHistoricalData
import pandas as pd

# %%
key = open('api.txt').read()
client = EodHistoricalData(key)

# %%
data = pd.DataFrame(client.get_fundamental_equity('AAPL'))

# %%
data.loc['Balance_Sheet']['Financials']
# Out:
# {'currency_symbol': 'USD',
#  'quarterly': {'2023-12-31': {'date': '2023-12-31',
#    'filing_date': '2024-02-02',
#    'currency_symbol': 'USD',
#    'totalAssets': '353514000000.00',
#    'intangibleAssets': None,
#    'earningAssets': None,
#    'otherCurrentAssets': '40887000000.00',
#    'totalLiab': '279414000000.00',
#    'totalStockholderEquity': '74100000000.00',
#    'deferredLongTermLiab': None,
#    'otherCurrentLiab': '65565000000.00',
#    'commonStock': '75236000000.00',
#    'capitalStock': '75236000000.00',
#    'retainedEarnings': '8242000000.00',
#    'otherLiab': None,
#    'goodWill': None,
#    'otherAssets': None,
#    'cash': '40760000000.00',
#    'cashAndEquivalents': None,
#    'totalCurrentLiabilities': '133973000000.00',
#    'currentDeferredRevenue': '8264000000.00',
#    'netDebt': '56326000000.00',
#    'shortTermDebt': '1998000000.00',
#    'shortLongTermDebt': '12952000000.00',
#    'shortLongTermDebtTotal': '97086000000.00',
# ...
